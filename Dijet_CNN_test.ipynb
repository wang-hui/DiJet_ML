# %%
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd
#pd.set_option('display.max_rows', 200)
pd.set_option("display.max_columns", 999)
import uproot
import os
from multiprocessing import Pool
import psutil

import tensorflow as tf
print(tf.__version__)
print(tf.test.is_built_with_cuda())
# Out:
# 2023-09-09 11:30:40.101118: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-09 11:30:40.320939: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2.10.0
# True

# %%
def get_min(Ref, Array):
    return np.argmin(np.abs(Ref - Array))

# %%
def add_more_cols(DF):
    DF["P1M"] = (DF["Mjj_msortedP1_high"] + DF["Mjj_msortedP1_low"]) / 2
    DF["P2M"] = (DF["Mjj_msortedP2_high"] + DF["Mjj_msortedP2_low"]) / 2
    DF["P3M"] = (DF["Mjj_msortedP3_high"] + DF["Mjj_msortedP3_low"]) / 2
    
    DF["dRi"] = DF.apply(lambda row: get_min(row["Mjj_avg_dRpairing_GeV"], 
                                np.array([row["P1M"], row["P2M"], row["P3M"]])), axis = 1)
    DF["Truth_high"] = DF.apply(lambda row: get_min(row["Mass"], np.array([row["Mjj_msortedP1_high"], 
                                row["Mjj_msortedP2_high"], row["Mjj_msortedP3_high"]])), axis = 1)
    DF["Truth_avg"] = DF.apply(lambda row: get_min(row["Mass"], 
                                np.array([row["P1M"], row["P2M"], row["P3M"]])), axis = 1)
    
    DF["P1QSMD"] = (DF["Mjj_msortedP1_high"] - DF["Mass"])**2 + (DF["Mjj_msortedP1_low"] - DF["Mass"])**2
    DF["P2QSMD"] = (DF["Mjj_msortedP2_high"] - DF["Mass"])**2 + (DF["Mjj_msortedP2_low"] - DF["Mass"])**2
    DF["P3QSMD"] = (DF["Mjj_msortedP3_high"] - DF["Mass"])**2 + (DF["Mjj_msortedP3_low"] - DF["Mass"])**2
    
    DF["Truth_QSMD"] = DF.apply(lambda row: get_min(0, 
                                np.array([row["P1QSMD"], row["P2QSMD"], row["P3QSMD"]])), axis = 1)
    
    DF["y1_sum"] = abs(DF["y12"] + DF["y34"])
    DF["y1_diff"] = abs(DF["y12"] - DF["y34"])
    DF["y2_sum"] = abs(DF["y13"] + DF["y24"])
    DF["y2_diff"] = abs(DF["y13"] - DF["y24"])
    DF["y3_sum"] = abs(DF["y14"] + DF["y23"])
    DF["y3_diff"] = abs(DF["y14"] - DF["y23"])

# %%
def normalize_inouts(DF):
    GevCols = ["Mjj_msortedP1_high", "Mjj_msortedP1_low", "Mjj_msortedP2_high", "Mjj_msortedP2_low", 
               "Mjj_msortedP3_high", "Mjj_msortedP3_low", "Mjj_avg_dRpairing_GeV",
               "pt_ordered_jet1_pt", "pt_ordered_jet2_pt", "pt_ordered_jet3_pt", "pt_ordered_jet4_pt"]
    for GevCol in GevCols:
        DF[GevCol] = DF[GevCol] / 1000
        
    return DF

# %%
def make_training_and_testing_pd(Mass):
    TrainingRows = 100000
    TestingRows = 50000
    File = "ML_TTree/tree_ML_MCRun2_" + str(Mass) + "GeV.root"
    
    print("Processing file: " + File + "\n")
    Events = uproot.open(File)["tree_ML"]
    DF = Events.arrays(library="pd")
    DF = DF.loc[DF["evt_trig"] == 1].reset_index(drop=True)
    DF["Mass"] = Mass
    add_more_cols(DF)
    normalize_inouts(DF)
    
    TrainingDF = DF.loc[0:TrainingRows-1]
    TestingDF = DF.loc[TrainingRows:TrainingRows+TestingRows-1]
    
    return [TrainingDF, TestingDF]

# %%
Masses = [500, 600, 700, 800, 900, 1000, 1250, 1500, 1750, 2000, 2500, 3000]

SanityCheckPlots = False
NotebookName = "quad_sum_mass_diff_CNN_Dropout"
ResultsDir = "results_temp/results_" + NotebookName + "/"
if not os.path.exists(ResultsDir):
    os.makedirs(ResultsDir)

# %%
#multithreading and memory monitoring in case large input files in the future
Mem0 = psutil.virtual_memory().available

TrainingDF = None
TestingDF = None
with Pool(processes=6) as pool:
    DFarray = pool.map(make_training_and_testing_pd, Masses)
    TrainingDF =pd.concat([row[0] for row in DFarray], ignore_index=True)
    TestingDF = pd.concat([row[1] for row in DFarray], ignore_index=True)

Mem1 = psutil.virtual_memory().available
print("Memory used: " + str((Mem0 - Mem1)/(1024**3)) + "GB")
# Out:
# Processing file: ML_TTree/tree_ML_MCRun2_600GeV.root
# Processing file: ML_TTree/tree_ML_MCRun2_500GeV.root
# Processing file: ML_TTree/tree_ML_MCRun2_900GeV.root
#
#
#
# Processing file: ML_TTree/tree_ML_MCRun2_700GeV.root
# Processing file: ML_TTree/tree_ML_MCRun2_800GeV.root
# Processing file: ML_TTree/tree_ML_MCRun2_1000GeV.root
#
#
#
# Processing file: ML_TTree/tree_ML_MCRun2_1250GeV.root
#
# Processing file: ML_TTree/tree_ML_MCRun2_1500GeV.root
#
# Processing file: ML_TTree/tree_ML_MCRun2_1750GeV.root
#
# Processing file: ML_TTree/tree_ML_MCRun2_2000GeV.root
#
# Processing file: ML_TTree/tree_ML_MCRun2_2500GeV.root
#
# Processing file: ML_TTree/tree_ML_MCRun2_3000GeV.root
#
# Memory used: 0.9824409484863281GB

# %%
#remove a mass point in training and check its performace in testing
#TrainingDF = TrainingDF.loc[TrainingDF["Mass"] != 1000]
TrainingDF
# Out:
#               y12       y34       y13       y24       y14       y23  \
# 0        0.459736 -0.731325  0.492579 -0.572288 -0.136930  0.075227
# 1        0.177537 -0.046975  0.196526  0.058371  0.045306  0.222323
# 2        1.138567 -0.880824 -0.476845  1.483183  0.345174  0.359891
# 3        0.750664 -1.096145  0.298671 -0.234110  0.306175 -0.194680
# 4       -0.508460 -0.847235 -0.673451 -0.477038 -0.610471 -0.564505
# ...           ...       ...       ...       ...       ...       ...
# 1199995 -0.123482 -0.125765  0.073410 -0.459019  0.051655 -0.416842
# 1199996 -0.604223 -0.543135 -0.408403 -0.912209 -0.513081 -0.700012
# 1199997 -0.395082  1.192083  0.071781  0.499111 -0.059069  0.595599
# 1199998 -0.073569 -0.724779 -0.297034 -0.373384 -0.091503 -0.579088
# 1199999 -0.214394 -0.418738 -0.588272  0.182048 -0.123040 -0.466964
#
#          fourjetmasstev  Mjj_msortedP1_high_div4jm  Mjj_msortedP2_high_div4jm  \
# 0              1.437438                   0.589512                   0.483189
# 1              1.372216                   0.731474                   0.360959
# 2              2.415887                   0.773636                   0.421770
# 3              1.927872                   0.589096                   0.496342
# 4              1.149871                   0.741729                   0.417437
# ...                 ...                        ...                        ...
# 1199995        5.470423                   0.777138                   0.448219
# 1199996        5.158958                   0.643059                   0.572051
# 1199997        6.064116                   0.491871                   0.475817
# 1199998        5.248789                   0.540463                   0.491500
# 1199999        4.803051                   0.554413                   0.495174
#
#          Mjj_msortedP3_high_div4jm  Mjj_msortedP1_high  Mjj_msortedP1_low  \
# 0
# 4        0.045966
# ...           ...
# 1199995  0.468497
# 1199996  0.186931
# 1199997  0.654667
# 1199998  0.487585
# 1199999  0.343924
#
# [1200000 rows x 51 columns]

# %%
TrainingDF.dtypes
# Out:
# y12                          float32
# y34                          float32
# y13                          float32
# y24                          float32
# y14                          float32
# y23                          float32
# fourjetmasstev               float64
# Mjj_msortedP1_high_div4jm    float64
# Mjj_msortedP2_high_div4jm    float64
# Mjj_msortedP3_high_div4jm    float64
# Mjj_msortedP1_high           float64
# Mjj_msortedP1_low            float64
# Mjj_msortedP2_high           float64
# Mjj_msortedP2_low            float64
# Mjj_msortedP3_high           float64
# Mjj_msortedP3_low            float64
# Mjj_avg_dRpairing_GeV        float32
# pt_ordered_jet1_pt           float32
# pt_ordered_jet1_eta          float32
# pt_ordered_jet1_phi          float32
# pt_ordered_jet1_m            float32
# pt_ordered_jet2_pt           float32
# pt_ordered_jet2_eta          float32
# pt_ordered_jet2_phi          float32
# pt_ordered_jet2_m            float32
# pt_ordered_jet3_pt           float32
# pt_ordered_jet3_eta          float32
# pt_ordered_jet3_phi          float32
# pt_ordered_jet3_m            float32
# pt_ordered_jet4_pt           float32
# pt_ordered_jet4_eta          float32
# pt_ordered_jet4_phi          float32
# pt_ordered_jet4_m            float32
# evt_trig                       int32
# Mass                           int64
# P1M                          float64
# P2M                          float64
# P3M                          float64
# dRi                            int64
# Truth_high                     int64
# Truth_avg                      int64
# P1QSMD                       float64
# P2QSMD                       float64
# P3QSMD                       float64
# Truth_QSMD                     int64
# y1_sum                       float32
# y1_diff                      float32
# y2_sum                       float32
# y2_diff                      float32
# y3_sum                       float32
# y3_diff                      float32
# dtype: object

# %%
if SanityCheckPlots:
    plt.hist(TrainingDF["Mass"], bins = int((Masses[-1] - Masses[0])/50) + 1,
             range = [Masses[0]-25, Masses[-1]+25], rwidth = 1)
    plt.xlabel("Gen mass [GeV]")
    plt.ylabel("Events")
    plt.title("Training Sample")

# %%
if SanityCheckPlots:
    plt.hist(TestingDF["Mass"], bins = int((Masses[-1] - Masses[0])/50) + 1,
             range = [Masses[0]-25, Masses[-1]+25], rwidth = 1)
    plt.xlabel("Gen mass [GeV]")
    plt.ylabel("Events")
    plt.title("Testing Sample")

# %%
if SanityCheckPlots:
    plt.hist2d(TrainingDF["fourjetmasstev"], TrainingDF["Mjj_msortedP2_high_div4jm"],
               bins = 200, range = [[0.5,10], [0.25,0.65]], norm = "log")
    plt.xlabel("fourjetmasstev")
    plt.ylabel("Mjj_msortedP2_high_div4jm")
    plt.colorbar()

# %%
if SanityCheckPlots:
    for i, Mass in enumerate(Masses):
        TrainingDF_temp = TrainingDF.loc[TrainingDF["Mass"] == Mass]
        if len(TrainingDF_temp.index) == 0: continue
        plt.hist2d(TrainingDF_temp["fourjetmasstev"], TrainingDF_temp["Mjj_msortedP2_high_div4jm"],
                   bins = 200, range = [[Mass/1000, Mass/1000 + 3 + 0.4*i], [0.25,0.65]], norm = "log")
        #plt.scatter(TrainingDF_temp["fourjetmasstev"], TrainingDF_temp["Mjj_msortedP2_high_div4jm"])
        plt.title("Gen mass " + str(Mass) + " GeV")
        plt.xlabel("fourjetmasstev")
        plt.ylabel("Mjj_msortedP2_high_div4jm")
        plt.colorbar()
        plt.show()

# %%
CNNinputs = []
for i in range(1,5):
    CNNinputs.append("pt_ordered_jet" + str(i) + "_pt")
    CNNinputs.append("pt_ordered_jet" + str(i) + "_eta")
    CNNinputs.append("pt_ordered_jet" + str(i) + "_phi")
    CNNinputs.append("pt_ordered_jet" + str(i) + "_m")
print (CNNinputs)

DNNInputs = ["fourjetmasstev", "Mjj_msortedP1_high", "Mjj_msortedP1_low", "Mjj_msortedP2_high", "Mjj_msortedP2_low",
             "Mjj_msortedP3_high", "Mjj_msortedP3_low"]
# Out:
# ['pt_ordered_jet1_pt', 'pt_ordered_jet1_eta', 'pt_ordered_jet1_phi', 'pt_ordered_jet1_m', 'pt_ordered_jet2_pt', 'pt_ordered_jet2_eta', 'pt_ordered_jet2_phi', 'pt_ordered_jet2_m', 'pt_ordered_jet3_pt', 'pt_ordered_jet3_eta', 'pt_ordered_jet3_phi', 'pt_ordered_jet3_m', 'pt_ordered_jet4_pt', 'pt_ordered_jet4_eta', 'pt_ordered_jet4_phi', 'pt_ordered_jet4_m']

# %%
TrainingInputs_DNN = TrainingDF[DNNInputs].to_numpy()
TrainingInputs_CNN = TrainingDF[CNNinputs].to_numpy()
TrainingTruth = TrainingDF["Truth_QSMD"].to_numpy()

TestingInputs_DNN = TestingDF[DNNInputs].to_numpy()
TestingInputs_CNN = TestingDF[CNNinputs].to_numpy()

# %%
print(TrainingInputs_DNN.shape)
print(TrainingInputs_CNN.shape)
print(TrainingTruth.shape)

print(TestingInputs_DNN.shape)
print(TestingInputs_CNN.shape)
# Out:
# (1200000, 7)
# (1200000, 16)
# (1200000,)
# (600000, 7)
# (600000, 16)

# %%
def model_CNN_Dropout():
    cnn_input  = tf.keras.Input(shape=(4*4, ), name="cnn_input")
    cnn_output = tf.keras.layers.Reshape((4,4, 1))(cnn_input)
    cnn_output = tf.keras.layers.Conv2D(16, (4,4), activation='relu') (cnn_output)
    cnn_output = tf.keras.layers.Flatten()(cnn_output)
    
    dnn_input  = tf.keras.Input(shape=(len(DNNInputs), ), name="dnn_input")
    dnn_output = tf.keras.layers.concatenate([cnn_output, dnn_input])
    
    dnn_output = tf.keras.layers.Dense(32, activation='relu')(dnn_output)
    dnn_output = tf.keras.layers.Dropout(0.5)(dnn_output)
    dnn_output = tf.keras.layers.Dense(16, activation='relu')(dnn_output)
    dnn_output = tf.keras.layers.Dropout(0.4)(dnn_output)
    dnn_output = tf.keras.layers.Dense(8, activation='relu')(dnn_output)
    dnn_output = tf.keras.layers.Dropout(0.3)(dnn_output)
    dnn_output = tf.keras.layers.Dense(3, activation='softmax', name="model_out")(dnn_output)

    Model = tf.keras.Model(inputs=[cnn_input, dnn_input], outputs=dnn_output, name = "ModelCNNDropout")
    Model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])
    return Model

# %%
def model_DNN_Dropout():
    Model = tf.keras.Sequential([
        tf.keras.Input(shape=(len(DNNInputs), ), name="model_in"),
        tf.keras.layers.Dense(32, activation='relu'),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(16, activation='relu'),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(8, activation='relu'),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(3, activation='softmax', name="model_out")],
        name = "ModelDNNDropout"
    )
    Model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])
    return Model

# %%
Model = model_CNN_Dropout()
#Model = model_DNN_Dropout()
# Out:
# 2023-09-09 11:32:00.572165: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-09 11:32:01.427399: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 11303 MB memory:  -> device: 0, name: Tesla P100-PCIE-12GB, pci bus id: 0000:65:00.0, compute capability: 6.0

# %%
Model.summary()
# Out:
# Model: "ModelCNNDropout"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  cnn_input (InputLayer)         [(None, 16)]         0           []
#
#  reshape (Reshape)              (None, 4, 4, 1)      0           ['cnn_input[0][0]']
#
#  conv2d (Conv2D)                (None, 1, 1, 16)     272         ['reshape[0][0]']
#
#  flatten (Flatten)              (None, 16)           0           ['conv2d[0][0]']
#
#  dnn_input (InputLayer)         [(None, 7)]          0           []
#
#  concatenate (Concatenate)      (None, 23)           0           ['flatten[0][0]',
#                                                                   'dnn_input[0][0]']
#
#  dense (Dense)                  (None, 32)           768         ['concatenate[0][0]']
#
#  dropout (Dropout)              (None, 32)           0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 16)           528         ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 16)           0           ['dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 8)            136         ['dropout_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 8)            0           ['dense_2[0][0]']
#
#  model_out (Dense)              (None, 3)            27          ['dropout_2[0][0]']
#
# ==================================================================================================
# Total params: 1,731
# Trainable params: 1,731
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
History = Model.fit({"cnn_input": TrainingInputs_CNN, "dnn_input": TrainingInputs_DNN}, TrainingTruth,
                    batch_size = 5000, epochs = 100, validation_split = 0.2)
# Out:
# Epoch 1/100
# 2023-09-09 11:32:03.211152: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8100
# 192/192 [==============================] - 3s 6ms/step - loss: 1.1395 - accuracy: 0.4378 - val_loss: 0.9317 - val_accuracy: 0.6216
# Epoch 2/100
# 192/192 [==============================] - 1s 3ms/step - loss: 0.9661 - accuracy: 0.4958 - val_loss: 0.7630 - val_accuracy: 0.6868
# Epoch 3/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.9117 - accuracy: 0.5406 - val_loss: 0.6678 - val_accuracy: 0.7163
# Epoch 4/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.8691 - accuracy: 0.5774 - val_loss: 0.6092 - val_accuracy: 0.7204
# Epoch 5/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.8367 - accuracy: 0.5999 - val_loss: 0.5757 - val_accuracy: 0.7433
# Epoch 6/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.8113 - accuracy: 0.6111 - val_loss: 0.5858 - val_accuracy: 0.7465
# Epoch 7/100
# 192/192 [==============================] - 1s 3ms/step - loss: 0.7783 - accuracy: 0.6260 - val_loss: 0.5538 - val_accuracy: 0.7608
# Epoch 8/100
# 192/192 [==============================] - 1s 3ms/step - loss: 0.7582 - accuracy: 0.6390 - val_loss: 0.5502 - val_accuracy: 0.8067
# Epoch 9/100
# 192/192 [==============================] - 1s 3ms/step - loss: 0.7475 - accuracy: 0.6479 - val_loss: 0.5513 - val_accuracy: 0.8155
# Epoch 10/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.7421 - accuracy: 0.6514 - val_loss: 0.5360 - val_accuracy: 0.8122
# Epoch 11/100
# 192/192 [==============================] - 1s 3ms/step - loss: 0.7378 - accuracy: 0.6535 - val_loss: 0.5425 - val_accuracy: 0.8179
# Epoch 12/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.7365 - accuracy: 0.6541 - val_loss: 0.5548 - val_accuracy: 0.8138
# Epoch 13/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.7338 - accuracy: 0.6559 - val_loss: 0.5461 - val_accuracy: 0.8190
# Epoch 14/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.7318 - accuracy: 0.6572 - val_loss: 0.5506 - val_accuracy: 0.8141
# Epoch 15/100
# 192/192 [==============================] - 1s 3ms/step - loss: 0.7295 - accuracy: 0.6581 - val_loss: 0.5508 - val_accuracy: 0.8094
# Epoch 16/100
# 192/192 [==============================] - 1s 3ms/step - loss: 0.7282 - accuracy: 0.6594 - val_loss: 0.5412 - val_accuracy: 0.8139
# Epoch 17/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.
100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.6526 - accuracy: 0.7110 - val_loss: 0.5340 - val_accuracy: 0.7989
# Epoch 79/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.6527 - accuracy: 0.7117 - val_loss: 0.5001 - val_accuracy: 0.8095
# Epoch 80/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.6520 - accuracy: 0.7121 - val_loss: 0.4978 - val_accuracy: 0.8144
# Epoch 81/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.6525 - accuracy: 0.7117 - val_loss: 0.5248 - val_accuracy: 0.8025
# Epoch 82/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.6522 - accuracy: 0.7116 - val_loss: 0.5210 - val_accuracy: 0.8009
# Epoch 83/100
# 192/192 [==============================] - 1s 3ms/step - loss: 0.6526 - accuracy: 0.7117 - val_loss: 0.5323 - val_accuracy: 0.8000
# Epoch 84/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.6518 - accuracy: 0.7130 - val_loss: 0.5201 - val_accuracy: 0.8054
# Epoch 85/100
# 192/192 [==============================] - 1s 3ms/step - loss: 0.6522 - accuracy: 0.7114 - val_loss: 0.5023 - val_accuracy: 0.8113
# Epoch 86/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.6509 - accuracy: 0.7119 - val_loss: 0.5282 - val_accuracy: 0.8036
# Epoch 87/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.6525 - accuracy: 0.7113 - val_loss: 0.5033 - val_accuracy: 0.8083
# Epoch 88/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.6517 - accuracy: 0.7113 - val_loss: 0.5247 - val_accuracy: 0.8027
# Epoch 89/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.6524 - accuracy: 0.7111 - val_loss: 0.5006 - val_accuracy: 0.8104
# Epoch 90/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.6511 - accuracy: 0.7111 - val_loss: 0.5077 - val_accuracy: 0.8100
# Epoch 91/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.6516 - accuracy: 0.7113 - val_loss: 0.5291 - val_accuracy: 0.8023
# Epoch 92/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.6531 - accuracy: 0.7105 - val_loss: 0.5211 - val_accuracy: 0.8074
# Epoch 93/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.6520 - accuracy: 0.7115 - val_loss: 0.5089 - val_accuracy: 0.8112
# Epoch 94/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.6526 - accuracy: 0.7110 - val_loss: 0.5360 - val_accuracy: 0.7972
# Epoch 95/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.6521 - accuracy: 0.7112 - val_loss: 0.5197 - val_accuracy: 0.8092
# Epoch 96/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.6525 - accuracy: 0.7114 - val_loss: 0.5384 - val_accuracy: 0.7963
# Epoch 97/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.6524 - accuracy: 0.7109 - val_loss: 0.5186 - val_accuracy: 0.8108
# Epoch 98/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.6523 - accuracy: 0.7107 - val_loss: 0.5020 - val_accuracy: 0.8049
# Epoch 99/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.6523 - accuracy: 0.7123 - val_loss: 0.5098 - val_accuracy: 0.8059
# Epoch 100/100
# 192/192 [==============================] - 1s 4ms/step - loss: 0.6529 - accuracy: 0.7114 - val_loss: 0.5056 - val_accuracy: 0.8112

# %%
Loss = History.history["loss"]
ValLoss = History.history["val_loss"]
Epochs = range(1, len(Loss) + 1)

plt.plot(Epochs, Loss, "r", label="Training loss")
plt.plot(Epochs, ValLoss, "b", label="Validation loss")
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("Loss")
    
plt.savefig(ResultsDir + "Loss_vs_Epochs.png")

# %%
Model.save(ResultsDir + "Model.h5")

ModelTest = tf.keras.models.load_model(ResultsDir + "Model.h5")
TestingOutputs = ModelTest.predict({"cnn_input": TestingInputs_CNN, "dnn_input": TestingInputs_DNN},
                                   batch_size = 5000)
# Out:
# 120/120 [==============================] - 0s 2ms/step

# %%
TestingOutputs[0] #ML raw output is the probability of 3 sparse categories
# Out:
# array([2.8045397e-04, 8.4204268e-01, 1.5767686e-01], dtype=float32)

# %%
TestingPredictions = np.argmax(TestingOutputs, axis = 1) #pick the highest probability as ML output

# %%
print(TestingPredictions.shape)
print(TestingPredictions[0])
# Out:
# (600000,)
# 1

# %%
TestingDF["Pred"] = TestingPredictions.tolist()

# %%
TestingDF
# Out:
#              y12       y34       y13       y24       y14       y23  \
# 0      -0.385314 -0.292828 -0.304943 -0.410875 -0.762117  0.063545
# 1      -0.217832 -0.006325 -0.125562 -0.156699 -0.164723 -0.116783
# 2       0.238854  0.581879  0.725073 -0.122710  0.206642  0.531022
# 3      -0.633889 -0.193005 -0.791055 -0.319948 -0.635317 -0.502395
# 4       0.687157  0.112902  0.555835  0.426765  0.607989  0.402100
# ...          ...       ...       ...       ...       ...       ...
# 599995 -1.316550  1.204935 -0.061761 -0.589233 -0.267516 -0.353778
# 599996  0.859281 -0.702321 -0.039884  0.664421  0.189909  0.353617
# 599997  0.154598 -1.328771 -0.289804 -0.618617  0.590000 -1.330350
# 599998  0.762512 -0.244654  0.491108  0.206219  0.157218  0.596648
# 599999 -0.169300 -0.603905  0.134912 -0.831512  0.098388 -0.749766
#
#         fourjetmasstev  Mjj_msortedP1_high_div4jm  Mjj_msortedP2_high_div4jm  \
# 0             1.665246                   0.650471                   0.406185
# 1             1.109070                   0.634266                   0.448905
# 2             1.522245                   0.581316                   0.488398
# 3             2.525532                   0.859122                   0.317233
# 4             1.569428                   0.596522                   0.572933
# ...                ...                        ...                        ...
# 599995        6.142254                   0.606728                   0.425973
# 599996        5.129152                   0.545517                   0.475153
# 599997        6.280539                   0.720415                   0.525028
# 599998        6.048077                   0.521897                   0.475347
# 599999        7.829708                   0.690826                   0.395780
#
#         Mjj_msortedP3_high_div4jm  Mjj_msortedP1_high  Mjj_msortedP1_low  \
# 0                        0.366546            1.083193           0.373950
# 1                        0.308877            0.703446           0.375377
# 2                        0.337147            0.884906           0.596236
# 3                        0.278710            2.169740           0.265412
# 4                        0.326371            0.936199           0.199743
# ...                           ...                 ...                ...
# 599995                   0.348761            3.726679           2.139488
# 599996                   0.400566            2.798038           1.912490
# 599997                   0.214241            4.524592           1.535514
# 599998                   0.354163            3.156473           2.037133
# 599999                   0.325881            5.408968           2.245739
#
#         Mjj_msortedP2_high  Mjj_msortedP2_low  Mjj_msortedP3_high  \
# 0                 0.676399           0.612059            0.610390
# 1                 0.497867           0.468088            0.342566
# 2                 0.743461           0.438657            0.513220
# 3                 0.801181           0.651792            0.703891
# 4                 0.899177           0.482994            0.512215
# ...                    ...                ...                 ...
# 599995            2.616437           2.594937            2.142181
# 599996            2.437130           2.124802            2.054564
# 599997            3.297457           1.661724            1.345551
# 599998            2.874936           2.729543            2.142006
# 599999            3.098845           2.465512            2.551557
#
#         Mjj_msortedP3_low  Mjj_avg_dRpairing_GeV  pt_ordered_jet1_pt  \
# 0                0.527888               0.569139            0.562562
# 1                0.128955               0.235760            0.361619
# 2                0.434524               0.473872            0.481394
# 3                0.241316               0.472604            1.214417
# 4                0.500105               0.567971            0.608950
# ...                   ...                    ...                 ...
# 599995           1.065793               2.605687            1.047794
# 599996           0.442143               1.248353            1.434423
# 599997           1.117768               1.231659            1.248180
# 599998           1.502817               1.822412            1.884198
# 599999           2.237812               2.394685            2.242530
#
#         pt_ordered_jet1_eta  pt_ordered_jet1_phi  pt_ordered_jet1_m  \
# 0
# 3               2  2.843065e+06  1.137507e+05  1.084890e+05           2
# 4               2  2.804235e+05  1.596315e+05  1.492244e+02           2
# ...           ...           ...           ...           ...         ...
# 599995          0  1.268544e+06  3.111970e+05  4.477012e+06           1
# 599996          0  1.223466e+06  1.082793e+06  7.436482e+06           1
# 599997          0  4.469101e+06  1.879463e+06  6.279999e+06           1
# 599998          1  9.515969e+05  8.878807e+04  2.977710e+06           1
# 599999          1  6.372035e+06  2.954482e+05  7.820311e+05           1
#
#           y1_sum   y1_diff    y2_sum   y2_diff    y3_sum   y3_diff  Pred
# 0       0.678142  0.092486  0.715818  0.105932  0.698572  0.825663     1
# 1       0.224157  0.211507  0.282261  0.031137  0.281507  0.047940     1
# 2       0.820733  0.343024  0.602363  0.847783  0.737664  0.324380     0
# 3       0.826894  0.440883  1.111003  0.471107  1.137712  0.132922     1
# 4       0.800059  0.574255  0.982600  0.129070  1.010089  0.205889     2
# ...          ...       ...       ...       ...       ...       ...   ...
# 599995  0.111615  2.521484  0.650994  0.527472  0.621295  0.086262     1
# 599996  0.156960  1.561602  0.624536  0.704305  0.543526  0.163708     1
# 599997  1.174173  1.483369  0.908421  0.328814  0.740350  1.920349     2
# 599998  0.517859  1.007166  0.697327  0.284889  0.753866  0.439430     1
# 599999  0.773205  0.434605  0.696600  0.966423  0.651378  0.848154     2
#
# [600000 rows x 52 columns]

# %%
AccPred = []
AccdR = []
Acc0 = []
Acc1 = []
Acc2 = []
for Mass in Masses:
    TestingDF_temp = TestingDF.loc[TestingDF["Mass"] == Mass]
    TestingDF_pred = TestingDF_temp.loc[TestingDF_temp["Pred"]==TestingDF_temp["Truth_QSMD"]]
    TestingDF_dR = TestingDF_temp.loc[TestingDF_temp["dRi"]==TestingDF_temp["Truth_QSMD"]]
    TestingDF_0 = TestingDF_temp.loc[0==TestingDF_temp["Truth_QSMD"]]
    TestingDF_1 = TestingDF_temp.loc[1==TestingDF_temp["Truth_QSMD"]]
    TestingDF_2 = TestingDF_temp.loc[2==TestingDF_temp["Truth_QSMD"]]

    AccPred.append(float(len(TestingDF_pred.index))/len(TestingDF_temp.index))
    AccdR.append(float(len(TestingDF_dR.index))/len(TestingDF_temp.index))
    Acc0.append(float(len(TestingDF_0.index))/len(TestingDF_temp.index))
    Acc1.append(float(len(TestingDF_1.index))/len(TestingDF_temp.index))
    Acc2.append(float(len(TestingDF_2.index))/len(TestingDF_temp.index))

# %%
AccPredAvg = "Avg %.2f" % float(sum(AccPred)/len(AccPred))
AccdRAvg = "Avg %.2f" % float(sum(AccdR)/len(AccdR))
Acc0Avg = "Avg %.2f" % float(sum(Acc0)/len(Acc0))
Acc1Avg = "Avg %.2f" % float(sum(Acc1)/len(Acc1))
Acc2Avg = "Avg %.2f" % float(sum(Acc2)/len(Acc2))

print(["%.2f" % i for i in AccPred], AccPredAvg)
print(["%.2f" % i for i in AccdR], AccdRAvg)
print(["%.2f" % i for i in Acc0], Acc0Avg)
print(["%.2f" % i for i in Acc1], Acc1Avg)
print(["%.2f" % i for i in Acc2], Acc2Avg)
# Out:
# ['0.66', '0.75', '0.78', '0.79', '0.79', '0.80', '0.80', '0.80', '0.80', '0.80', '0.81', '0.82'] Avg 0.78
# ['0.40', '0.26', '0.20', '0.18', '0.15', '0.14', '0.12', '0.11', '0.11', '0.11', '0.10', '0.07'] Avg 0.16
# ['0.04', '0.10', '0.14', '0.16', '0.17', '0.17', '0.19', '0.20', '0.19', '0.19', '0.17', '0.16'] Avg 0.16
# ['0.30', '0.40', '0.43', '0.46', '0.47', '0.48', '0.49', '0.51', '0.51', '0.51', '0.51', '0.54'] Avg 0.47
# ['0.65', '0.50', '0.43', '0.39', '0.37', '0.35', '0.32', '0.30', '0.29', '0.30', '0.32', '0.29'] Avg 0.37

# %%
plt.plot(Masses, AccPred, "r", label = "ML prediction(" + AccPredAvg + ")")
plt.plot(Masses, AccdR, "k", label = "dR pairing(" + AccdRAvg + ")")
plt.plot(Masses, Acc0, "g", label = "Always pair 1(" + Acc0Avg + ")")
plt.plot(Masses, Acc1, "b", label = "Always pair 2(" + Acc1Avg + ")")
plt.plot(Masses, Acc2, "y", label = "Always pair 3(" + Acc2Avg + ")")
plt.legend()
plt.xlabel("Gen mass [GeV]")
plt.ylabel("Accuracy")
plt.ylim(0, 1.4)
plt.savefig(ResultsDir + "Accuracy_vs_mass.png")

# %%
P1Mi = TestingDF.columns.get_loc("P1M")
#TestingDF["dR_M"] = TestingDF.apply(lambda row: row.iloc[row["dRi"]], axis=1)
TestingDF["dR_M"] = TestingDF.to_numpy()[np.arange(len(TestingDF)), P1Mi + TestingDF["dRi"]]
TestingDF["Truth_high_M"] = TestingDF.to_numpy()[np.arange(len(TestingDF)), P1Mi + TestingDF["Truth_high"]]
TestingDF["Truth_avg_M"] = TestingDF.to_numpy()[np.arange(len(TestingDF)), P1Mi + TestingDF["Truth_avg"]]
TestingDF["Pred_M"] = TestingDF.to_numpy()[np.arange(len(TestingDF)), P1Mi + TestingDF["Pred"]]
TestingDF
# Out:
#              y12       y34       y13       y24       y14       y23  \
# 0      -0.385314 -0.292828 -0.304943 -0.410875 -0.762117  0.063545
# 1      -0.217832 -0.006325 -0.125562 -0.156699 -0.164723 -0.116783
# 2       0.238854  0.581879  0.725073 -0.122710  0.206642  0.531022
# 3      -0.633889 -0.193005 -0.791055 -0.319948 -0.635317 -0.502395
# 4       0.687157  0.112902  0.555835  0.426765  0.607989  0.402100
# ...          ...       ...       ...       ...       ...       ...
# 599995 -1.316550  1.204935 -0.061761 -0.589233 -0.267516 -0.353778
# 599996  0.859281 -0.702321 -0.039884  0.664421  0.189909  0.353617
# 599997  0.154598 -1.328771 -0.289804 -0.618617  0.590000 -1.330350
# 599998  0.762512 -0.244654  0.491108  0.206219  0.157218  0.596648
# 599999 -0.169300 -0.603905  0.134912 -0.831512  0.098388 -0.749766
#
#         fourjetmasstev  Mjj_msortedP1_high_div4jm  Mjj_msortedP2_high_div4jm  \
# 0             1.665246                   0.650471                   0.406185
# 1             1.109070                   0.634266                   0.448905
# 2             1.522245                   0.581316                   0.488398
# 3             2.525532                   0.859122                   0.317233
# 4             1.569428                   0.596522                   0.572933
# ...                ...                        ...                        ...
# 599995        6.142254                   0.606728                   0.425973
# 599996        5.129152                   0.545517                   0.475153
# 599997        6.280539                   0.720415                   0.525028
# 599998        6.048077                   0.521897                   0.475347
# 599999        7.829708                   0.690826                   0.395780
#
#         Mjj_msortedP3_high_div4jm  Mjj_msortedP1_high  Mjj_msortedP1_low  \
# 0                        0
# ...             ...           ...          ...          ...
# 599995  2605.686776   2605.686776  2933.083412  2605.686776
# 599996  1248.353576   2355.264125  2355.264125  2280.966344
# 599997  1231.659470   2479.590718  3030.053233  1231.659470
# 599998  1822.411702   2802.239432  2802.239432  2802.239432
# 599999  2394.684634   2782.178174  2782.178174  2394.684634
#
# [600000 rows x 56 columns]

# %%
# for each gen mass sample, plot average dijet mass
for Mass in Masses:
    TestingDF_temp = TestingDF.loc[TestingDF["Mass"] == Mass]
    plt.figure()
    plt.hist(TestingDF_temp["Pred_M"], bins = 100, range = [Mass/3, Mass*1.5], histtype = "step", color = "r", label = "ML prediction")
    plt.hist(TestingDF_temp["dR_M"], bins = 100, range = [Mass/3, Mass*1.5], histtype = "step", color = "k", label = "dR pairing")
    plt.hist(TestingDF_temp["Truth_high_M"], bins = 100, range = [Mass/3, Mass*1.5], histtype = "step", color = "g", label = "Truth mass high")
    plt.hist(TestingDF_temp["Truth_avg_M"], bins = 100, range = [Mass/3, Mass*1.5], histtype = "step", color = "b", label = "Truth mass average")
    plt.legend()
    plt.title("Gen mass " + str(Mass) + " GeV")
    plt.xlabel("Average dijet mass [GeV]")
    plt.ylabel("Events")
    plt.savefig(ResultsDir + "Average_dijet_mass_" + str(Mass) + "GeV.png")

# %%
P1M_high_i = TestingDF.columns.get_loc("Mjj_msortedP1_high")
TestingDF["dR_M_high"] = TestingDF.to_numpy()[np.arange(len(TestingDF)), P1M_high_i + TestingDF["dRi"]*2] * 1000
TestingDF["Truth_high_M_high"] = TestingDF.to_numpy()[np.arange(len(TestingDF)), P1M_high_i + TestingDF["Truth_high"]*2] * 1000
TestingDF["Truth_avg_M_high"] = TestingDF.to_numpy()[np.arange(len(TestingDF)), P1M_high_i + TestingDF["Truth_avg"]*2] * 1000
TestingDF["Pred_M_high"] = TestingDF.to_numpy()[np.arange(len(TestingDF)), P1M_high_i + TestingDF["Pred"]*2] * 1000
TestingDF
# Out:
#              y12       y34       y13       y24       y14       y23  \
# 0      -0.385314 -0.292828 -0.304943 -0.410875 -0.762117  0.063545
# 1      -0.217832 -0.006325 -0.125562 -0.156699 -0.164723 -0.116783
# 2       0.238854  0.581879  0.725073 -0.122710  0.206642  0.531022
# 3      -0.633889 -0.193005 -0.791055 -0.319948 -0.635317 -0.502395
# 4       0.687157  0.112902  0.555835  0.426765  0.607989  0.402100
# ...          ...       ...       ...       ...       ...       ...
# 599995 -1.316550  1.204935 -0.061761 -0.589233 -0.267516 -0.353778
# 599996  0.859281 -0.702321 -0.039884  0.664421  0.189909  0.353617
# 599997  0.154598 -1.328771 -0.289804 -0.618617  0.590000 -1.330350
# 599998  0.762512 -0.244654  0.491108  0.206219  0.157218  0.596648
# 599999 -0.169300 -0.603905  0.134912 -0.831512  0.098388 -0.749766
#
#         fourjetmasstev  Mjj_msortedP1_high_div4jm  Mjj_msortedP2_high_div4jm  \
# 0             1.665246                   0.650471                   0.406185
# 1             1.109070                   0.634266                   0.448905
# 2             1.522245                   0.581316                   0.488398
# 3             2.525532                   0.859122                   0.317233
# 4             1.569428                   0.596522                   0.572933
# ...                ...                        ...                        ...
# 599995        6.142254                   0.606728                   0.425973
# 599996        5.129152                   0.545517                   0.475153
# 599997        6.280539                   0.720415                   0.525028
# 599998        6.048077                   0.521897                   0.475347
# 599999        7.829708                   0.690826                   0.395780
#
#         Mjj_msortedP3_high_div4jm  Mjj_msortedP1_high  Mjj_msortedP1_low  \
# 0                        0.366546            1.083193           0.373950
# 1                        0.308877            0.703446           0.375377
# 2                        0.337147            0.884906           0.596236
# 3                        0.278710            2.169740           0.265412
# 4                        0.326371            0.936199           0.199743
# ...                           ...                 ...                ...
# 599995                   0.348761            3.726679           2.139488
# 599996                   0.400566            2.798038           1.912490
# 599997                   0.214241            4.524592           1.535514
# 599998                   0.354163            3.156473           2.037133
# 599999                   0.325881            5.408968           2.245739
#
#         Mjj_msortedP2_high  Mjj_msortedP2_low  Mjj_msortedP3_high  \
# 0                 0
# 599997  1231.659470   2479.590718  3030.053233  1231.659470  1345.551306
# 599998  1822.411702   2802.239432  2802.239432  2802.239432  2142.006216
# 599999  2394.684634   2782.178174  2782.178174  2394.684634  2551.556798
#
#         Truth_high_M_high  Truth_avg_M_high  Pred_M_high
# 0              610.389668        610.389668   676.398680
# 1              497.867207        497.867207   497.867207
# 2              513.219915        513.219915   884.905691
# 3              703.891486        703.891486   801.180826
# 4              512.215294        512.215294   512.215294
# ...                   ...               ...          ...
# 599995        2616.436654       3726.679280  2616.436654
# 599996        2798.037987       2798.037987  2437.130249
# 599997        3297.457153       4524.592364  1345.551306
# 599998        2874.936016       2874.936016  2874.936016
# 599999        3098.844789       3098.844789  2551.556798
#
# [600000 rows x 60 columns]

# %%
# for each gen mass sample, plot dijet mass high
for Mass in Masses:
    TestingDF_temp = TestingDF.loc[TestingDF["Mass"] == Mass]
    plt.figure()
    plt.hist(TestingDF_temp["Pred_M_high"], bins = 100, range = [Mass/2, Mass*2], histtype = "step", color = "r", label = "ML prediction")
    plt.hist(TestingDF_temp["dR_M_high"], bins = 100, range = [Mass/2, Mass*2], histtype = "step", color = "k", label = "dR pairing")
    plt.hist(TestingDF_temp["Truth_high_M_high"], bins = 100, range = [Mass/2, Mass*2], histtype = "step", color = "g", label = "Truth mass high")
    plt.hist(TestingDF_temp["Truth_avg_M_high"], bins = 100, range = [Mass/2, Mass*2], histtype = "step", color = "b", label = "Truth mass average")
    plt.legend(loc="upper right")
    plt.title("Gen mass " + str(Mass) + " GeV")
    plt.xlabel("Dijet mass high [GeV]")
    plt.ylabel("Events")
    plt.savefig(ResultsDir + "Dijet_mass_high_" + str(Mass) + "GeV.png")

# %%
P1QSMDi = TestingDF.columns.get_loc("P1QSMD")
TestingDF["dR_QSMD"] = TestingDF.to_numpy()[np.arange(len(TestingDF)), P1QSMDi + TestingDF["dRi"]]
TestingDF["Truth_high_QSMD"] = TestingDF.to_numpy()[np.arange(len(TestingDF)), P1QSMDi + TestingDF["Truth_high"]]
TestingDF["Truth_avg_QSMD"] = TestingDF.to_numpy()[np.arange(len(TestingDF)), P1QSMDi + TestingDF["Truth_avg"]]
TestingDF["Pred_QSMD"] = TestingDF.to_numpy()[np.arange(len(TestingDF)), P1QSMDi + TestingDF["Pred"]]
TestingDF
# Out:
#              y12       y34       y13       y24       y14       y23  \
# 0      -0.385314 -0.292828 -0.304943 -0.410875 -0.762117  0.063545
# 1      -0.217832 -0.006325 -0.125562 -0.156699 -0.164723 -0.116783
# 2       0.238854  0.581879  0.725073 -0.122710  0.206642  0.531022
# 3      -0.633889 -0.193005 -0.791055 -0.319948 -0.635317 -0.502395
# 4       0.687157  0.112902  0.555835  0.426765  0.607989  0.402100
# ...          ...       ...       ...       ...       ...       ...
# 599995 -1.316550  1.204935 -0.061761 -0.589233 -0.267516 -0.353778
# 599996  0.859281 -0.702321 -0.039884  0.664421  0.189909  0.353617
# 599997  0.154598 -1.328771 -0.289804 -0.618617  0.590000 -1.330350
# 599998  0.762512 -0.244654  0.491108  0.206219  0.157218  0.596648
# 599999 -0.169300 -0.603905  0.134912 -0.831512  0.098388 -0.749766
#
#         fourjetmasstev  Mjj_msortedP1_high_div4jm  Mjj_msortedP2_high_div4jm  \
# 0             1.665246                   0.650471                   0.406185
# 1             1.109070                   0.634266                   0.448905
# 2             1.522245                   0.581316                   0.488398
# 3             2.525532                   0.859122                   0.317233
# 4             1.569428                   0.596522                   0.572933
# ...                ...                        ...                        ...
# 599995        6.142254                   0.606728                   0.425973
# 599996        5.129152                   0.545517                   0.475153
# 599997        6.280539                   0.720415                   0.525028
# 599998        6.048077                   0.521897                   0.475347
# 599999        7.829708                   0.690826                   0.395780
#
#         Mjj_msortedP3_high_div4jm  Mjj_msortedP1_high  Mjj_msortedP1_low  \
# 0                        0
# 0        569.138607    569.138607   569.138607   644.228805   610.389668
# 1        235.760461    482.977846   482.977846   482.977846   342.566192
# 2        473.871794    473.871794   473.871794   740.570848   513.219915
# 3        472.603865    472.603865   472.603865   726.486396   703.891486
# 4        567.971112    506.160069   506.160069   506.160069   936.198882
# ...             ...           ...          ...          ...          ...
# 599995  2605.686776   2605.686776  2933.083412  2605.686776  2616.436654
# 599996  1248.353576   2355.264125  2355.264125  2280.966344  2054.564499
# 599997  1231.659470   2479.590718  3030.053233  1231.659470  1345.551306
# 599998  1822.411702   2802.239432  2802.239432  2802.239432  2142.006216
# 599999  2394.684634   2782.178174  2782.178174  2394.684634  2551.556798
#
#         Truth_high_M_high  Truth_avg_M_high  Pred_M_high       dR_QSMD  \
# 0              610.389668        610.389668   676.398680  1.296359e+04
# 1              497.867207        497.867207   497.867207  1.624600e+05
# 2              513.219915        513.219915   884.905691  4.461916e+03
# 3              703.891486        703.891486   801.180826  1.084890e+05
# 4              512.215294        512.215294   512.215294  2.804235e+05
# ...                   ...               ...          ...           ...
# 599995        2616.436654       3726.679280  2616.436654  3.111970e+05
# 599996        2798.037987       2798.037987  2437.130249  7.436482e+06
# 599997        3297.457153       4524.592364  1345.551306  6.279999e+06
# 599998        2874.936016       2874.936016  2874.936016  2.977710e+06
# 599999        3098.844789       3098.844789  2551.556798  7.820311e+05
#
#         Truth_high_QSMD  Truth_avg_QSMD     Pred_QSMD
# 0          1.296359e+04    1.296359e+04  4.367370e+04
# 1          1.022894e+03    1.022894e+03  1.022894e+03
# 2          4.461916e+03    4.461916e+03  1.574138e+05
# 3          1.084890e+05    1.084890e+05  1.137507e+05
# 4          1.492244e+02    1.492244e+02  1.492244e+02
# ...                 ...             ...           ...
# 599995     3.111970e+05    1.268544e+06  3.111970e+05
# 599996     1.223466e+06    1.223466e+06  1.082793e+06
# 599997     1.879463e+06    4.469101e+06  6.279999e+06
# 599998     8.878807e+04    8.878807e+04  8.878807e+04
# 599999     2.954482e+05    2.954482e+05  7.820311e+05
#
# [600000 rows x 64 columns]

# %%
# for each gen mass sample, plot sum (mjj - gen mass)^2
for Mass in Masses:
    TestingDF_temp = TestingDF.loc[TestingDF["Mass"] == Mass]
    Bins = [10**(x/5) for x in range(5,40)]
    plt.figure()
    plt.hist(TestingDF_temp["Pred_QSMD"], bins = Bins, histtype = "step", color = "r", label = "ML prediction")
    plt.hist(TestingDF_temp["dR_QSMD"], bins = Bins, histtype = "step", color = "k", label = "dR pairing")
    plt.hist(TestingDF_temp["Truth_high_QSMD"], bins = Bins, histtype = "step", color = "g", label = "Truth mass high")
    plt.hist(TestingDF_temp["Truth_avg_QSMD"], bins = Bins, histtype = "step", color = "b", label = "Truth mass average")
    plt.xscale('log')
    plt.legend()
    plt.title("Gen mass " + str(Mass) + " GeV")
    plt.xlabel("sum (mjj - gen mass)^2 [GeV^2]")
    plt.ylabel("Events")
    plt.savefig(ResultsDir + "Quad_sum_mass_diff_" + str(Mass) + "GeV.png")
